# %%
# importing packages:
import cv2
import numpy as np
import os # hepls to interact with the operating system
import matplotlib.pyplot as plt
import pickle # help to zip/compress the image file in byte(binary)

# %%
# accessing the images present inside "Emotion":
# getcwd :- fetching the current working directory.
img_dir = os.path.join(os.getcwd(),"Emotion")

# %%
# to checking the directory where currently we working:
print(os.getcwd())
# Out:
# C:\Users\tw2b\Downloads\AIML\Real Time Emotion detection

# %%
# creating a path to store the pickle files inside data folder.
img_final = os.path.join(os.getcwd(),"data")

# %%
# to store all the input(images) and output(labels) in different [].
images = []
labels = []

# %%
# performing image preprocessing and saving the files.
# listdir: to list all folders/file in any directory.
for i in os.listdir(img_dir):
    for j in os.listdir(os.path.join(img_dir,i)):
        img_path = os.path.join(os.path.join(img_dir,i),j)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img,(48,48))
        images.append(img)
        labels.append(i.split(' ')[0])
    print(i,'---> Completed')
# Out:
# angry ---> Completed
# happy ---> Completed
# neutral ---> Completed
# sad ---> Completed
# surprised ---> Completed

# %%
set(labels)
# Out:
# {'angry', 'happy', 'neutral', 'sad', 'surprised'}

# %%
images = np.array(images)
labels = np.array(labels)

# %%
images.shape
# Out:
# (16083, 48, 48)

# %%
# to plot an image after preprocessing.
plt.imshow(images[1000], cmap='gray')
plt.show()

# %%
# Pickling the images and lebels files.
with open(os.path.join(img_final,'images.p'),'wb') as f:
    pickle.dump(images,f)

with open (os.path.join(img_final,'labels.p'),'wb') as f:
    pickle.dump(labels,f)
